# %% [markdown]
# # Open Food Facts — Data Quality
# A concise, reproducible analysis. Set `DATA_PATH` to a locally downloaded official export; raw data is never committed.

# %%
from pathlib import Path
import pandas as pd
from off_quality import clean_products, missingness

DATA_PATH = Path('../data/raw/openfoodfacts.csv')

# %%
products = pd.read_csv(DATA_PATH, sep='\t', low_memory=False)
missingness(products).head(20)

# %%
clean, report = clean_products(products)
report, clean.head()
