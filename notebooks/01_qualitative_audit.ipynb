# %% [markdown]
# # 01 — Qualitative data audit
# Understand meaning before calculating statistics.

# %%
data_dictionary = {
 'code':'product barcode; must remain text',
 'product_name':'multilingual free text',
 'energy_100g':'numeric energy per 100 g; unit must be verified',
 'nutrition_grade_fr':'ordered category with documented vocabulary'}
data_dictionary

# %% [markdown]
# Check language, measurement units, category vocabularies and plausible ranges with domain documentation before defining cleaning rules.
