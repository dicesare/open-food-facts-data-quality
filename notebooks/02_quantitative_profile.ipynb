# %% [markdown]
# # 02 — Quantitative profile
# Measure sparsity, cardinality and distribution shape before reducing the dataset.

# %%
profile = [
 {'column':'product_name','missing_rate':.08,'unique_rate':.84},
 {'column':'energy_100g','missing_rate':.19,'unique_rate':.04},
 {'column':'nutrition_grade_fr','missing_rate':.31,'unique_rate':.0001}]
sorted(profile, key=lambda x:x['missing_rate'], reverse=True)

# %% [markdown]
# Missingness is a property to investigate, not an automatic reason to discard a column. Analyse it by country, category and update period.
