# %% [markdown]
# # 04 — Data-quality scorecard
# Summarise quality by dimension without hiding the underlying measures.
#
# **Illustrative example:** the numbers below are placeholders, not measured historical results or pipeline output. See 00 for computed fixture results and 06 for historical evidence.

# %%
scorecard = {
 'completeness':.81,
 'barcode_validity':.97,
 'record_uniqueness':.95,
 'nutrition_consistency':.89}
round(sum(scorecard.values())/len(scorecard), 3), scorecard

# %% [markdown]
# A composite score is navigation, not truth. Keep thresholds versioned and expose each dimension to avoid masking a critical weakness.
