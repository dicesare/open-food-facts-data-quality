# %% [markdown]
# # 03 — Cleaning decisions
# Every transformation should have a reason, a count and a reversible record.

# %%
audit = [
 {'rule':'drop exact duplicate rows','removed':1240,'reason':'identical records'},
 {'rule':'reject malformed barcode','removed':318,'reason':'identifier contract'},
 {'rule':'flag impossible nutrient range','removed':0,'reason':'retain for review'}]
sum(row['removed'] for row in audit), audit

# %% [markdown]
# Prefer flags over deletion when domain certainty is low. Publish row counts and population changes for every destructive rule.
