# %% [markdown]
# # 05 — Interactive quality report
# Translate Plotly/Voilà exploration into a stable reporting contract.

# %%
report_contract = {
 'filters':['country','category','updated_period'],
 'cards':['rows','completeness','duplicates','invalid_ranges'],
 'charts':['missingness','nutrition_distributions','rule_impact'],
 'export':['quality_report.json']}
report_contract

# %% [markdown]
# Keep visualisation optional so validation and tests run headlessly. The same metrics can power notebooks, CI artifacts or a dashboard.
